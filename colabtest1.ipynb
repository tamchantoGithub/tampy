# %% [markdown]
# <a href="https://colab.research.google.com/github/tamchantoGithub/tampy/blob/main/colabtest1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
# from pandas import Series
s1 = pd.Series([1,2,3,4,5])
print(s1)

list1=["a1","a2","a3"]
pd.DataFrame(data=list1)
#df = pd.Dataframe(np.random(20,2))
#print('Random Top 5')
#df.head()
#print('Random Botom 5')
#df.tail()
#print('Random Top 5 & Botom 10')
#df.head().append(df.tail())
#print('Random Top 3 & Botom 3')
#df.head(3).append(df.tail(3))

#arr1 = np.array([[1,2,3],[21,22,23],[31,32,33]])
#pd.DataFrame(data=arr1)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64
#     0
# 0  a1
# 1  a2
# 2  a3

# %%
arr1 = np.array([[1,2,3],[21,22,23],[31,32,33]])
pd.DataFrame(data=arr1)
# Out:
#     0   1   2
# 0   1   2   3
# 1  21  22  23
# 2  31  32  33

# %%
index1 = ["Row1","Row2","Row3"]
columun1 = ["Col1","Col2","Col3"]
pd.DataFrame(data=arr1,index=index1,columns=columun1)
# Out:
#       Col1  Col2  Col3
# Row1     1     2     3
# Row2    21    22    23
# Row3    31    32    33

# %%
# ignore index
#pd.DataFrame(data=arr1,index=index1,columns=columun1)
list2 = [["P001", "iPhone 8 64GB", 85000],
         ["P002", "iPhone X 256GB", 130000],
         ["P003", "iPhone SE 32GB", 37000]]
column2 = ["Product ID", "Product Name", "Price（JPY）"]
df1 = pd.DataFrame(data=list2,columns=column2)
df1
# Out:
#   Product ID    Product Name  Price（JPY）
# 0       P001   iPhone 8 64GB       85000
# 1       P002  iPhone X 256GB      130000
# 2       P003  iPhone SE 32GB       37000

# %%
# @title Price（JPY）

from matplotlib import pyplot as plt
df1['Price（JPY）'].plot(kind='hist', bins=20, title='Price（JPY）')
plt.gca().spines[['top', 'right',]].set_visible(False)
# Out:
# /usr/local/lib/python3.11/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 65288 (\N{FULLWIDTH LEFT PARENTHESIS}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 65289 (\N{FULLWIDTH RIGHT PARENTHESIS}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 65288 (\N{FULLWIDTH LEFT PARENTHESIS}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 65289 (\N{FULLWIDTH RIGHT PARENTHESIS}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
df2 = pd.DataFrame(data= [["P004", "iPhone 7 32GB", 10000]],
                   columns=column2)
df2
# Out:
#   Product ID   Product Name  Price（JPY）
# 0       P004  iPhone 7 32GB       10000

# %%
df1=df1.append(df2, ignore=index = True)
df1
