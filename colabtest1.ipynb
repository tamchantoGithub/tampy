# %% [markdown]
# <a href="https://colab.research.google.com/github/tamchantoGithub/tampy/blob/main/colabtest1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install torch
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 61.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 52.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 32.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 4.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 10.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 78.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
# ...

# %%
# %pip show torch
# Out:
# Name: torch
# Version: 2.6.0+cu124
# Summary: Tensors and Dynamic neural networks in Python with strong GPU acceleration
# Home-page: https://pytorch.org/
# Author: PyTorch Team
# Author-email: packages@pytorch.org
# License: BSD-3-Clause
# Location: /usr/local/lib/python3.11/dist-packages
# Requires: filelock, fsspec, jinja2, networkx, nvidia-cublas-cu12, nvidia-cuda-cupti-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-runtime-cu12, nvidia-cudnn-cu12, nvidia-cufft-cu12, nvidia-curand-cu12, nvidia-cusolver-cu12, nvidia-cusparse-cu12, nvidia-cusparselt-cu12, nvidia-nccl-cu12, nvidia-nvjitlink-cu12, nvidia-nvtx-cu12, sympy, triton, typing-extensions
# Required-by: accelerate, fastai, peft, sentence-transformers, timm, torchaudio, torchvision

# %%
import torch
x = torch.rand(5, 3)
print(x)
# Out:
# tensor([[0.0139, 0.9486, 0.7881],
#         [0.0312, 0.1998, 0.6861],
#         [0.4522, 0.2860, 0.3535],
#         [0.3865, 0.9807, 0.4769],
#         [0.4107, 0.5647, 0.3840]])

# %%
# %pip install torchvision

# %%
# pytorch.tensor
import torch
import torch.nn as nn
#import torch.nn.functional as F
#import torch.optim as optim
#from torch.utils.data import Dataset, DataLoader
import matplotlib.pyplot as plt
import numpy as np
import time

n = np.linspace(0,1,5)
t =torch.linspace(0,1,5)
print(n)
print(t)
# Out:
# [0.   0.25 0.5  0.75 1.  ]
# tensor([0.0000, 0.2500, 0.5000, 0.7500, 1.0000])

# %%
import torchvision
import torch
x = torch.rand(5, 3)
print(x)

trans = torchvision.transforms.ToTensor()

#trans = torcvision.transforms.ToTensor()
#trans = torcvision.transforms.Compose([torcvision.transforms.ToTensor(),torcvision.transforms.Normalize((0.5,),(0.5,))])
class Plus2(object):
  def __init__(self):
    pass
  def __call__(self,x):
    data = x+2
    return data
trans = Plus2()
x=9
data=trans(x)
print(x)
print(data)

seconds_in_aday = 24*60*60
print(f'seconds_in_aday is...:{seconds_in_aday} sec')
# Out:
# tensor([[0.1118, 0.1419, 0.7833],
#         [0.3785, 0.3541, 0.2979],
#         [0.0084, 0.0151, 0.5979],
#         [0.6523, 0.6604, 0.1178],
#         [0.8731, 0.5372, 0.8160]])
# 9
# 11
# seconds_in_aday is...:86400 sec

# %%
import numpy as np
from matplotlib import pyplot as plt

y = 200 + np.random.randn(100)
x = [x for x in range(len(y))]

plt.plot(x, y, '-')
